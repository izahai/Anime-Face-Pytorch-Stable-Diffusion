# %%
# !git clone https://github.com/izahai/Anime-Face-Pytorch-Stable-Diffusion.git

# %%
# !pip install huggingface_hub
from huggingface_hub import hf_hub_download

path = hf_hub_download(
    repo_id="ngynthhai/vae-gan-128ch-8z",
    filename="epoch24.pt",
    repo_type="model",
    local_dir="/content/Anime-Face-Pytorch-Stable-Diffusion/", 
)

print("Downloaded to", path)

# %%
# %cd Anime-Face-Pytorch-Stable-Diffusion
# !chmod +x scripts/train_ldm.sh
# !./scripts/train_ldm.sh
